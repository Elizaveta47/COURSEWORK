# %%
import pandas as pd
import numpy as np

file_path = '/Users/elizaveta/Downloads/TCGA_GBM_sampleMap_HT_HG-U133A.csv'

data = pd.read_csv(file_path)

# Отображение первых нескольких строк данных
print("First few lines of the data:")
print(data.head())

# Проверка структуры данных
print("\nData structure:")
print(data.info())

# Проверка на пропущенные значения
print("\nMissing values in each column:")
print(data.isnull().sum())



# Пример фильтрации данных: выбор только определенных генов
genes_of_interest = ['EGFR', 'PTEN', 'TP53', 'MDM2', 'CDK4']

filtered_data = data[data['sample'].isin(genes_of_interest)]

# Отображение отфильтрованных данных
print("\nFiltered data:")
print(filtered_data)
# Out:
# First few lines of the data:
#    sample  TCGA-27-1833-01  TCGA-06-0881-01  TCGA-27-1831-01  TCGA-16-1060-01  \
# 0   RNF14         7.789769         7.265982         8.149647         6.545897
# 1  UBE2Q1         8.769730         9.723571         7.854319         9.185205
# 2   RNF17         4.365812         4.378591         4.430541         4.323942
# 3   RNF10         6.835145         7.360954         6.609598         6.609051
# 4   RNF11         9.674176         9.394143        10.095775         8.815518
#
#    TCGA-02-0258-01  TCGA-06-0238-01  TCGA-06-0125-01  TCGA-12-1099-01  \
# 0         6.458360         6.563774         7.774005         6.774404
# 1         9.504754         8.274661         8.907024         9.376550
# 2         4.352047         4.393564         4.295439         4.203091
# 3         7.358946         6.100001         6.767017         6.749485
# 4         9.393797         9.104866         9.280288         9.758273
#
# ...

# %%
aggregated_data = filtered_data.groupby('sample').mean()

# Сброс индексов для удобства построения графика
aggregated_data = aggregated_data.reset_index()

# Проверка агрегированных данных
print(aggregated_data)
# Out:
#   sample  TCGA-27-1833-01  TCGA-06-0881-01  TCGA-27-1831-01  TCGA-16-1060-01  \
# 0   CDK4        10.962541         9.395162         9.742876         9.492448
# 1   EGFR         8.386675         7.392949         7.656815         8.870164
# 2   MDM2         4.289641         4.630747         4.528681         4.500250
# 3   PTEN         4.846676         6.454419         5.771885         5.065775
# 4   TP53         6.446618         5.955886         5.658816         5.259678
#
#    TCGA-02-0258-01  TCGA-06-0238-01  TCGA-06-0125-01  TCGA-12-1099-01  \
# 0        10.310148        12.558569         9.609362         9.544215
# 1         6.642822         4.712607         9.675797         6.380601
# 2         4.294666         4.384346         4.388569         4.488798
# 3         5.203588         4.945485         4.536383         4.901197
# 4         5.811356         5.770657         6.700117         5.621577
#
#    TCGA-06-0216-01  ...  TCGA-02-0111-01  TCGA-08-0512-01  TCGA-19-0955-01  \
# ...
